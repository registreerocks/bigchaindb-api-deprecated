# %%
from pymongo import MongoClient
from bigchaindb_driver import BigchainDB
import time

# %%
MDB = MongoClient('localhost', 27017)
BDB = BigchainDB('http://localhost:9984')

# %%
MDB.list_database_names()
# Out:
# ['admin', 'bigchain', 'config', 'local']

# %%
mbc = MDB.bigchain

# %%
mbc.list_collection_names()
# Out:
# ['transactions',
#  'validators',
#  'elections',
#  'pre_commit',
#  'metadata',
#  'abci_chains',
#  'blocks',
#  'assets',
#  'utxos']

# %%
for a in mbc.assets.find({'data.asset_type':'university'}):
    print(a)
# Out:
# {'_id': ObjectId('5bf0099802943d0001a738b8'), 'data': {'asset_type': 'university', 'name': 'University of Cape Town', 'physical_address': 'Rondebosch, Cape Town, 7700', 'short': 'UCT'}, 'id': 'a50bb3c754dde6013a4369c1ad6bc7bee325a2591d81a135f9ba7cb3ac279c51'}

# %%
for m in mbc.metadata.find({'id': 'a50bb3c754dde6013a4369c1ad6bc7bee325a2591d81a135f9ba7cb3ac279c51'}):
    print(m)
# Out:
# {'_id': ObjectId('5bf0099802943d0001a738b7'), 'id': 'a50bb3c754dde6013a4369c1ad6bc7bee325a2591d81a135f9ba7cb3ac279c51', 'metadata': {'timestamp': '2018-07-20'}}

# %%
for a in mbc.assets.find({'data.asset_type':'mark', 'data.student_address': '4'}):
    print(a)
    for m in mbc.metadata.find({'id': a['id']}):
        print(m)
# Out:
# {'_id': ObjectId('5bf009bb02943d0001a73b37'), 'data': {'asset_type': 'mark', 'course_id': '7b39a57a1479948460b78b5bab1036db1d7d518c40bb697e1b2c716cc34a5a82', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Class Participation'}, 'id': 'e436b248398fa7ac9d62c021fcfcd238b6dac6fc7087ad9679b2863bc867c578'}
# {'_id': ObjectId('5bf009bb02943d0001a73b36'), 'id': 'e436b248398fa7ac9d62c021fcfcd238b6dac6fc7087ad9679b2863bc867c578', 'metadata': {'mark': 50, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bc02943d0001a73b3b'), 'data': {'asset_type': 'mark', 'course_id': '7b39a57a1479948460b78b5bab1036db1d7d518c40bb697e1b2c716cc34a5a82', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorial Participation'}, 'id': 'b6d7dc94258dde625fed71aba723d9c4f082875e19eeef170bcbd0d39b82e13d'}
# {'_id': ObjectId('5bf009bc02943d0001a73b3a'), 'id': 'b6d7dc94258dde625fed71aba723d9c4f082875e19eeef170bcbd0d39b82e13d', 'metadata': {'mark': 53, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bc02943d0001a73b3f'), 'data': {'asset_type': 'mark', 'course_id': '7b39a57a1479948460b78b5bab1036db1d7d518c40bb697e1b2c716cc34a5a82', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': 'a15938beb1bcc3addbb1b0a7b590f8801b3d433f8f942389d7cfeb606655c539'}
# {'_id': ObjectId('5bf009bc02943d0001a73b3e'), 'id': 'a15938beb1bcc3addbb1b0a7b590f8801b3d433f8f942389d7cfeb606655c539', 'metadata': {'mark': 62, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bc02943d0001a73b43'), 'data': {'asset_type': 'mark', 'course_id': '7b39a57a1479948460b78b5bab1036db1d7d518c40bb697e1b2c716cc34a5a82', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Group Project'}, 'id': '23136512e0616d91a416f4d99e792feb87c31c4f4a35f7c00aaf9c3f90b8cc0b'}
# {'_id': ObjectId('5bf009bc02943d0001a73b42'), 'id': '23136512e0616d91a416f4d99e792feb87c31c4f4a35f7c00aaf9c3f90b8cc0b', 'metadata': {'mark': 91, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bc02943d0001a73b47'), 'data': {'asset_type': 'mark', 'course_id': '7b39a57a1479948460b78b5bab1036db1d7d518c40bb697e1b2c716cc34a5a82', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorial'}, 'id': 'ce6c4876e080bb20db14514968835e92851f717024556f6e5245191f30352db8'}
# {'_id': ObjectId('5bf009bc02943d0001a73b46'), 'id': 'ce6c4876e080bb20db14514968835e92851f717024556f6e5245191f30352db8', 'metadata': {'mark': 56, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bd02943d0001a73b4b'), 'data': {'asset_type': 'mark', 'course_id': '82f8ad578f16f24825e13bca9fa6c2673c3f33ab62c2469ddbfe883607b93ca0', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': 'c6d445ff923636dd5e9a1b506e4a554e077846943b285e90e95110c460e17514'}
# {'_id': ObjectId('5bf009bd02943d0001a73b4a'), 'id': 'c6d445ff923636dd5e9a1b506e4a554e077846943b285e90e95110c460e17514', 'metadata': {'mark': 75, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bd02943d0001a73b4f'), 'data': {'asset_type': 'mark', 'course_id': '82f8ad578f16f24825e13bca9fa6c2673c3f33ab62c2469ddbfe883607b93ca0', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': 'f536a32a2d5e0fd179c304eaa9f0e1396734f6804bce006d377e6f2a5090188b'}
# {'_id': ObjectId('5bf009bd02943d0001a73b4e'), 'id': 'f536a32a2d5e0fd179c304eaa9f0e1396734f6804bce006d377e6f2a5090188b', 'metadata': {'mark': 48, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bd02943d0001a73b53'), 'data': {'asset_type': 'mark', 'course_id': '82f8ad578f16f24825e13bca9fa6c2673c3f33ab62c2469ddbfe883607b93ca0', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '5a16ba3040ea73339f57462e963c95aa4080a94b21bad6e270da5333c559dfba'}
# {'_id': ObjectId('5bf009bd02943d0001a73b52'), 'id': '5a16ba3040ea73339f57462e963c95aa4080a94b21bad6e270da5333c559dfba', 'metadata': {'mark': 96, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bd02943d0001a73b57'), 'data': {'asset_type': 'mark', 'course_id': '82f8ad578f16f24825e13bca9fa6c2673c3f33ab62c2469ddbfe883607b93ca0', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': 'f5e0cdc33ca6aab3c571aa5c2b12d067700488f3f8424608b5b74a59e95e33a6'}
# {'_id': ObjectId('5bf009bd02943d0001a73b56'), 'id': 'f5e0cdc33ca6aab3c571aa5c2b12d067700488f3f8424608b5b74a59e95e33a6', 'metadata': {'mark': 53, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bd02943d0001a73b5b'), 'data': {'asset_type': 'mark', 'course_id': '47e930af9aa37586cab1b4fe3d74912c69791a194d164e5889d5d5bb26ad8bc7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '8ff1990d503952122f32b27a2e898749bd614cddd09b36dc39adf14b65b754a6'}
# {'_id': ObjectId('5bf009bd02943d0001a73b5a'), 'id': '8ff1990d503952122f32b27a2e898749bd614cddd09b36dc39adf14b65b754a6', 'metadata': {'mark': 82, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009be02943d0001a73b5f'), 'data': {'asset_type': 'mark', 'course_id': '47e930af9aa37586cab1b4fe3d74912c69791a194d164e5889d5d5bb26ad8bc7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': '93c97de7d89bd0894638d3531deb000786b5fa344b1ff1c6b6893582c0b0a957'}
# {'_id': ObjectId('5bf009be02943d0001a73b5e'), 'id': '93c97de7d89bd0894638d3531deb000786b5fa344b1ff1c6b6893582c0b0a957', 'metadata': {'mark': 78, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009be02943d0001a73b63'), 'data': {'asset_type': 'mark', 'course_id': '47e930af9aa37586cab1b4fe3d74912c69791a194d164e5889d5d5bb26ad8bc7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '990db85dc7501285184f9473cb8ff2907d21168419e4e59b55704f62531e450d'}
# {'_id': ObjectId('5bf009be02943d0001a73b62'), 'id': '990db85dc7501285184f9473cb8ff2907d21168419e4e59b55704f62531e450d', 'metadata': {'mark': 88, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009be02943d0001a73b67'), 'data': {'asset_type': 'mark', 'course_id': '47e930af9aa37586cab1b4fe3d74912c69791a194d164e5889d5d5bb26ad8bc7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': 'd4968752e19aab63127d246418c79b0cf668ad8f50b8805aca4bfa9584fcccc6'}
# {'_id': ObjectId('5bf009be02943d0001a73b66'), 'id': 'd4968752e19aab63127d246418c79b0cf668ad8f50b8805aca4bfa9584fcccc6', 'metadata': {'mark': 87, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009be02943d0001a73b6b'), 'data': {'asset_type': 'mark', 'course_id': 'c0866f465623557195624d30ee470ddf38e75736f2630f55462216edee1dad30', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '49e7b8ac1c762311bbbc4b6a8612302787ffafe8f23790268d2f95a5ba51d5c6'}
# {'_id': ObjectId('5bf009be02943d0001a73b6a'), 'id': '49e7b8ac1c762311bbbc4b6a8612302787ffafe8f23790268d2f95a5ba51d5c6', 'metadata': {'mark': 60, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009be02943d0001a73b6f'), 'data': {'asset_type': 'mark', 'course_id': 'c0866f465623557195624d30ee470ddf38e75736f2630f55462216edee1dad30', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': '4383a809778051e2719506bce2e9cb76f50751e6168e52072f046ac9d59f96c8'}
# {'_id': ObjectId('5bf009be02943d0001a73b6e'), 'id': '4383a809778051e2719506bce2e9cb76f50751e6168e52072f046ac9d59f96c8', 'metadata': {'mark': 86, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bf02943d0001a73b73'), 'data': {'asset_type': 'mark', 'course_id': 'c0866f465623557195624d30ee470ddf38e75736f2630f55462216edee1dad30', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '5556e4feb2b1430e06df91f51682025f99b1a5c6852040ce02cbd457a2d8dfc0'}
# {'_id': ObjectId('5bf009bf02943d0001a73b72'), 'id': '5556e4feb2b1430e06df91f51682025f99b1a5c6852040ce02cbd457a2d8dfc0', 'metadata': {'mark': 76, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bf02943d0001a73b77'), 'data': {'asset_type': 'mark', 'course_id': 'c0866f465623557195624d30ee470ddf38e75736f2630f55462216edee1dad30', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': '9d387c600db76811e36b89daa66326ab6f5f4680aad39a6319ffd52eeacba976'}
# {'_id': ObjectId('5bf009bf02943d0001a73b76'), 'id': '9d387c600db76811e36b89daa66326ab6f5f4680aad39a6319ffd52eeacba976', 'metadata': {'mark': 75, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bf02943d0001a73b7b'), 'data': {'asset_type': 'mark', 'course_id': 'fb3ba7d4779407e85c707c9279f3d1fc3a899596a45335800a92c34f6f5e52e7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '3d268425fd74a71601b1d4de8221cc0cba41e71def0059de644a9cd919679732'}
# {'_id': ObjectId('5bf009bf02943d0001a73b7a'), 'id': '3d268425fd74a71601b1d4de8221cc0cba41e71def0059de644a9cd919679732', 'metadata': {'mark': 57, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009bf02943d0001a73b7f'), 'data': {'asset_type': 'mark', 'course_id': 'fb3ba7d4779407e85c707c9279f3d1fc3a899596a45335800a92c34f6f5e52e7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': '122d78b48e84329652d281e7d56718457c0dbdb1826755e9d6c5f54c448f46e7'}
# {'_id': ObjectId('5bf009bf02943d0001a73b7e'), 'id': '122d78b48e84329652d281e7d56718457c0dbdb1826755e9d6c5f54c448f46e7', 'metadata': {'mark': 68, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c002943d0001a73b83'), 'data': {'asset_type': 'mark', 'course_id': 'fb3ba7d4779407e85c707c9279f3d1fc3a899596a45335800a92c34f6f5e52e7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '4ffbe26caff445647450da766fa76fe31324b18ac48ed1b23bde9d99ea044bdb'}
# {'_id': ObjectId('5bf009c002943d0001a73b82'), 'id': '4ffbe26caff445647450da766fa76fe31324b18ac48ed1b23bde9d99ea044bdb', 'metadata': {'mark': 75, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c002943d0001a73b87'), 'data': {'asset_type': 'mark', 'course_id': 'fb3ba7d4779407e85c707c9279f3d1fc3a899596a45335800a92c34f6f5e52e7', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': '350ca3c8d0d2ebf0fedbc34a391d514505c24ace5a190981c51093635b4d7a41'}
# {'_id': ObjectId('5bf009c002943d0001a73b86'), 'id': '350ca3c8d0d2ebf0fedbc34a391d514505c24ace5a190981c51093635b4d7a41', 'metadata': {'mark': 54, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c002943d0001a73b8b'), 'data': {'asset_type': 'mark', 'course_id': '621e7f3e01bf8d80f8aaf82efc026337a95d8fdbef2ac1c1f522d04257e938f6', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '904867f48cbca387fd1453e41871040a2959602f46375f8040c6463151dad1e5'}
# {'_id': ObjectId('5bf009c002943d0001a73b8a'), 'id': '904867f48cbca387fd1453e41871040a2959602f46375f8040c6463151dad1e5', 'metadata': {'mark': 66, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c002943d0001a73b8f'), 'data': {'asset_type': 'mark', 'course_id': '621e7f3e01bf8d80f8aaf82efc026337a95d8fdbef2ac1c1f522d04257e938f6', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': 'dafc3442ca561216314090e0fe90ba6e66b01cf304b36b6f70b6321036e29e0a'}
# {'_id': ObjectId('5bf009c002943d0001a73b8e'), 'id': 'dafc3442ca561216314090e0fe90ba6e66b01cf304b36b6f70b6321036e29e0a', 'metadata': {'mark': 58, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c002943d0001a73b93'), 'data': {'asset_type': 'mark', 'course_id': '621e7f3e01bf8d80f8aaf82efc026337a95d8fdbef2ac1c1f522d04257e938f6', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '4373575b590e0224fb9a6c4814d05ceae65bf0666ae3e6eec6511a3fd22f0214'}
# {'_id': ObjectId('5bf009c002943d0001a73b92'), 'id': '4373575b590e0224fb9a6c4814d05ceae65bf0666ae3e6eec6511a3fd22f0214', 'metadata': {'mark': 95, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c102943d0001a73b97'), 'data': {'asset_type': 'mark', 'course_id': '621e7f3e01bf8d80f8aaf82efc026337a95d8fdbef2ac1c1f522d04257e938f6', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': '5dce9f7729de3cac96f9bd9d6572ee2883e9831d7fc06eb5de9457f8f33efadf'}
# {'_id': ObjectId('5bf009c102943d0001a73b96'), 'id': '5dce9f7729de3cac96f9bd9d6572ee2883e9831d7fc06eb5de9457f8f33efadf', 'metadata': {'mark': 94, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c102943d0001a73b9b'), 'data': {'asset_type': 'mark', 'course_id': '836e4ac16a83c4f554a9eb8e04d2d318e01dc957a417508073ffbdc1e4ec2a50', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '98775a001bf851dc5f15eb62775156ed52a9f2147329a25bbd9cc8107422d1da'}
# {'_id': ObjectId('5bf009c102943d0001a73b9a'), 'id': '98775a001bf851dc5f15eb62775156ed52a9f2147329a25bbd9cc8107422d1da', 'metadata': {'mark': 80, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c102943d0001a73b9f'), 'data': {'asset_type': 'mark', 'course_id': '836e4ac16a83c4f554a9eb8e04d2d318e01dc957a417508073ffbdc1e4ec2a50', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': 'ac3771eea5201a1c0d02a3b7744f1aa86e212bf2bf69a8a9ce01d65ae7e602f7'}
# {'_id': ObjectId('5bf009c102943d0001a73b9e'), 'id': 'ac3771eea5201a1c0d02a3b7744f1aa86e212bf2bf69a8a9ce01d65ae7e602f7', 'metadata': {'mark': 84, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c102943d0001a73ba3'), 'data': {'asset_type': 'mark', 'course_id': '836e4ac16a83c4f554a9eb8e04d2d318e01dc957a417508073ffbdc1e4ec2a50', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': 'f6a9da494ca6b736c5df940dbb2bd31605b9824893e0c9d509b0851d4534e0d5'}
# {'_id': ObjectId('5bf009c102943d0001a73ba2'), 'id': 'f6a9da494ca6b736c5df940dbb2bd31605b9824893e0c9d509b0851d4534e0d5', 'metadata': {'mark': 98, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c202943d0001a73ba7'), 'data': {'asset_type': 'mark', 'course_id': '836e4ac16a83c4f554a9eb8e04d2d318e01dc957a417508073ffbdc1e4ec2a50', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': '479924d41544f7770d2f3e7b93e6697c97fd25e86982f935a82d1065c4aed2f1'}
# {'_id': ObjectId('5bf009c202943d0001a73ba6'), 'id': '479924d41544f7770d2f3e7b93e6697c97fd25e86982f935a82d1065c4aed2f1', 'metadata': {'mark': 72, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c202943d0001a73bab'), 'data': {'asset_type': 'mark', 'course_id': 'f48ecc6f866ea1b3ea18e2c6317d8de09da6ba38ffbd075a5905599f3bd51138', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '43fdec63b503d8bf9111367c8f120ffcb9f4e42da5e76d90887ed6eaae202456'}
# {'_id': ObjectId('5bf009c202943d0001a73baa'), 'id': '43fdec63b503d8bf9111367c8f120ffcb9f4e42da5e76d90887ed6eaae202456', 'metadata': {'mark': 99, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c202943d0001a73baf'), 'data': {'asset_type': 'mark', 'course_id': 'f48ecc6f866ea1b3ea18e2c6317d8de09da6ba38ffbd075a5905599f3bd51138', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': '004ae5899462f8ee94bb61ced70b1e3b71e706571e98f2580decc9b4ff0bf272'}
# {'_id': ObjectId('5bf009c202943d0001a73bae'), 'id': '004ae5899462f8ee94bb61ced70b1e3b71e706571e98f2580decc9b4ff0bf272', 'metadata': {'mark': 66, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c202943d0001a73bb3'), 'data': {'asset_type': 'mark', 'course_id': 'f48ecc6f866ea1b3ea18e2c6317d8de09da6ba38ffbd075a5905599f3bd51138', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '173c5361629bc9bd78a4cdf6b63f8931ae971aedce19131b1b4d069ee069a066'}
# {'_id': ObjectId('5bf009c202943d0001a73bb2'), 'id': '173c5361629bc9bd78a4cdf6b63f8931ae971aedce19131b1b4d069ee069a066', 'metadata': {'mark': 79, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c202943d0001a73bb7'), 'data': {'asset_type': 'mark', 'course_id': 'f48ecc6f866ea1b3ea18e2c6317d8de09da6ba38ffbd075a5905599f3bd51138', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': '6582b7eceb286b19eabc5a2916eabaf0f13eebc80719b96c093f17f82121398a'}
# {'_id': ObjectId('5bf009c202943d0001a73bb6'), 'id': '6582b7eceb286b19eabc5a2916eabaf0f13eebc80719b96c093f17f82121398a', 'metadata': {'mark': 51, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c302943d0001a73bbb'), 'data': {'asset_type': 'mark', 'course_id': 'fee7c7a0e4bd488edd96dcfbb2e089cd8be38e48ee4ef61c570ee634ea0a9e4e', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Test'}, 'id': '7535a322e99e49eb0f5922edc78f28992b8e733f6bf0e6603b38b433d8fbf7e4'}
# {'_id': ObjectId('5bf009c302943d0001a73bba'), 'id': '7535a322e99e49eb0f5922edc78f28992b8e733f6bf0e6603b38b433d8fbf7e4', 'metadata': {'mark': 48, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c302943d0001a73bbf'), 'data': {'asset_type': 'mark', 'course_id': 'fee7c7a0e4bd488edd96dcfbb2e089cd8be38e48ee4ef61c570ee634ea0a9e4e', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Project'}, 'id': '298576403e89cd4a8deac15c662d58d40bb8b4a4b157737efb60cfbe06513e63'}
# {'_id': ObjectId('5bf009c302943d0001a73bbe'), 'id': '298576403e89cd4a8deac15c662d58d40bb8b4a4b157737efb60cfbe06513e63', 'metadata': {'mark': 61, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c302943d0001a73bc3'), 'data': {'asset_type': 'mark', 'course_id': 'fee7c7a0e4bd488edd96dcfbb2e089cd8be38e48ee4ef61c570ee634ea0a9e4e', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Tutorials'}, 'id': '364b6aa68d654b39afba2a54cda01b1bdfd3f1828db84d609a5f810bd462c2df'}
# {'_id': ObjectId('5bf009c302943d0001a73bc2'), 'id': '364b6aa68d654b39afba2a54cda01b1bdfd3f1828db84d609a5f810bd462c2df', 'metadata': {'mark': 94, 'timestamp': '2018-08-03'}}
# {'_id': ObjectId('5bf009c302943d0001a73bc7'), 'data': {'asset_type': 'mark', 'course_id': 'fee7c7a0e4bd488edd96dcfbb2e089cd8be38e48ee4ef61c570ee634ea0a9e4e', 'degree_id': '8068da528a0a53b44006ae4de900fa34830e0a782a8c3693b02351b331cd0118', 'student_address': '4', 'type': 'Exam'}, 'id': 'a967e35e2cfceccb5883a6768513ada349fa45b54c090c871dcc66f5501c85e4'}
# {'_id': ObjectId('5bf009c302943d0001a73bc6'), 'id': 'a967e35e2cfceccb5883a6768513ada349fa45b54c090c871dcc66f5501c85e4', 'metadata': {'mark': 67, 'timestamp': '2018-08-03'}}

# %%
def _get_marks_by_student(address):
    files = BDB.assets.get(search=address)
    (files, course_data) = _retrieve_course_data(files, address)
    degree_data = _retrieve_degree_data(files)
    mark_data = _retrieve_mark_data(files, course_data)
    return {'degree_data': degree_data, 'mark_data': mark_data}

def _retrieve_degree_data(files):
    if files:
        degree_id = files[0].get('data').get('degree_id')
        degree = BDB.transactions.get(asset_id=degree_id)
        degree_data = {
            'name': degree[0].get('asset').get('data').get('name'),
            'level': degree[0].get('asset').get('data').get('level'),
            'courses': degree[-1].get('metadata').get('courses')
        }
        return degree_data

def _retrieve_course_data(files, address):
    (files, course_ids) = _retrieve_course_ids(files, address)
    course_data = _retrieve_course_information(course_ids)
    return (files, course_data)

def _retrieve_course_ids(files, address):
    courses = []
    for f in files[:]:
        if (f.get('data').get('asset_type') == 'mark') and (f.get('data').get('student_address') == address):
            courses.append(f.get('data').get('course_id'))
        else:
            files.remove(f)
    return (files, list(set(courses)))

def _retrieve_course_information(course_ids):
    course_data = dict()
    for course_id in course_ids:
        course = BDB.transactions.get(asset_id=course_id)
        course_data[course_id] = {
            'name': course[0].get('asset').get('data').get('name'), 
            'lecturer': course[0].get('asset').get('data').get('lecturer'),
            'components': course[-1].get('metadata').get('components')
        }
    return course_data

def _retrieve_mark_data(mark_files, course_data):
    mark_data = dict()
    for f in mark_files:
        course_id = f.get('data').get('course_id')
        mark_type = f.get('data').get('type')
        mark_file = BDB.transactions.get(asset_id=f.get('id'))[-1]
        mark = mark_file.get('metadata').get('mark')
        timestamp = mark_file.get('metadata').get('timestamp')
        weighting = (item for item in course_data.get(course_id).get('components') if item["type"] == mark_type).__next__().get('weighting')
        if mark_data.get(course_id):
            mark_data.get(course_id).get('components')[mark_type] = {
                'mark': mark, 
                'weighting': weighting, 
                'timestamp': timestamp
            }
            if mark_data.get(course_id).get('year') < timestamp[:4]:
                mark_data.get(course_id)['year'] = timestamp[:4]
        else:
            mark_data[course_id] = {
                'name': course_data.get(course_id).get('name'), 
                'lecturer': course_data.get(course_id).get('lecturer'), 
                'year': timestamp[:4],
                'components': {
                    mark_type: {
                        'mark': mark, 
                        'weighting': weighting, 
                        'timestamp': timestamp
                    }
                }
            }
    return mark_data

def _get_assets_by_key(asset, key, value, meta_flag):
    files = BDB.assets.get(search=value)
    assets = []
    for f in files:
        if (f.get('data').get('asset_type') == asset) and (f.get('data').get(key) == value):
            if meta_flag:
                asset_id = f.get('id')
                metadata = BDB.transactions.get(asset_id=asset_id)[-1].get('metadata')
                assets.append({**f, **{'metadata': metadata}})
            else: 
                assets.append(f)
    return assets

def _get_course_marks_by_lecturer(lecturer):
    courses = _get_assets_by_key('course', 'lecturer', lecturer, True)
    course_ids = [item.get('id') for item in courses]
    marks_per_course = dict()
    student_addresses = set()
    for i, course_id in enumerate(course_ids):
        marks = _get_assets_by_key('mark', 'course_id', course_id, True)
        course_marks = dict()
        for mark in marks:
            student_address = mark.get('data').get('student_address')
            mark_data = {'id': mark.get('id'), 'type': mark.get('data').get('type'), 'mark': mark.get('metadata').get('mark')}
            if not course_marks.get(student_address):
                course_marks[student_address] = [mark_data]
            else:
                course_marks[student_address].append(mark_data)
            student_addresses.add(student_address)
        marks_per_course[course_id] = {'name': courses[i].get('data').get('name'), 'components': courses[i].get('metadata').get('components'), 'course_marks': course_marks}
    return {'student_addresses': list(student_addresses), 'marks_per_course': marks_per_course}

# %%
_get_course_marks_by_lecturer('Allan Davids')
# Out:
# {'student_addresses': ['8',
#   '3',
#   '5',
#   '7',
#   '10',
#   '11',
#   '4',
#   '12',
#   '9',
#   '6',
#   '1',
#   '2',
#   '0',
#   '13'],
#  'marks_per_course': {'fb3ba7d4779407e85c707c9279f3d1fc3a899596a45335800a92c34f6f5e52e7': {'name': 'Data Visualization',
#    'components': [{'required': True, 'type': 'Test', 'weighting': 0.15},
#     {'required': True, 'type': 'Project', 'weighting': 0.45},
#     {'required': True, 'type': 'Tutorials', 'weighting': 0.1},
#     {'required': True, 'type': 'Exam', 'weighting': 0.3}],
#    'course_marks': {'0': [{'id': '2c1a183d553058ad93930c857cf9c8e1b322ecedb0f7b60cfeed124b71bd2fbd',
#       'type': 'Test',
#       'mark': 65},
#      {'id': 'cecb612d408caa4baf01cf7b874b5fcb035740b0d99639be146a6e3987b6620f',
#       'type': 'Project',
#       'mark': 74},
#      {'id': '279eb50574631a9fb7c98c757ad2c6752dbc769e74d6ac69bad7a482d79d56e0',
#       'type': 'Tutorials',
#       'mark': 88},
#      {'id': 'f90482480ed3f71ce91838e2e6014fb2da42adb8021bca32c64a805df219c2d3',
#       'type': 'Exam',
#       'mark': 85}],
#     '1': [{'id': '6c28b2493e5b2fe45c7ea6062b699c73da13cb52bcd851ce0e4d3539a4678065',
#       'type': 'Test',
#       'mark': 55},
#      {'id': 'bbbc207b323e90ef16501501bd3ff3f4f1da1c2a396e25aacbb1d8fd14abc134',
#       'type': 'Project',
#       'mark': 84},
#      {'id': 'fe24ce2bd48d63454461340c9de68fe832bbb123814c2e49b72e60c6a7c65a16',
#       'type': 'Tutorials',
#       'mark': 55},
#      {'id': 'c7e7a5915698768e5432d9868634ad1996169ffa1381ac52723837025cb91f57',
#       'type': 'Exam',
#       'mark': 93}],
#     '2': [{'id': '6b60bc19c99181ce3e19cbe62ea4a1c784fac785290659cf67cc2f48431d6de8',
#       'type': 'Test',
#       'mark': 68},
#      {'id': 'd9c03e8209b11f1d461ebee60ba2c261e2da1b61d8db717e65a66244c4596dfd',
#       'type': 'Project',
#       'mark': 63},
#      {'id': '6593f229ed67a80442cf5541772e001d74e3088352db29a724c33911e3621e8c',
#       'type': 'Tutorials',
#       'mark': 73},
#      {'id': '435a9f55df271a5e8e0deb4751cc6686422bc9acee7bd15410d2ac54f480a0dd',
#       'type': 'Exam',
#       'mark': 86}],
#     '3': [{'id': 'a18a0cbec4c8fa1279b19712fec21763a292dbb0c3814739e820e8d3acdae9e7',
#       'type': 'Test',
#       'mark': 75},
#      {'id': '41509fc1e444a01e3697159c451fd97c5c1482de77d5dac85b9c9897c57fcfc7',
#       'type': 'Project',
#       'mark': 66},
#      {'id': '07f9ee5131c0a3bc75c49039e0bf6418b1b14efae08a5ccfe8d838c559adb655',
#       'type': 'Tutorials',
#       'mark': 48},
#      {'id': 'eda517032c5df12db4d783856dafb16d218728818f9a79e9317f9425919ab991',
#       'type': 'Exam',
#       'mark': 88}],
#     '4': [{'id': '3d268425fd74a71601b1d4de8221cc0cba41e71def0059de644a9cd919679732',
#       'type': 'Test',
#       'mark': 57},
#      {'id': '122d78b48e84329652d281e7d56718457c0dbdb1826755e9d6c5f54c448f46e7',
#       'type': 'Project',
#       'mark': 68},
#      {'id': '4ffbe26caff445647450da766fa76fe31324b18ac48ed1b23bde9d99ea044bdb',
#       'type': 'Tutorials',
#       'mark': 75},
#      {'id': '350ca3c8d0d2ebf0fedbc34a391d514505c24ace5a190981c51093635b4d7a41',
#       'type': 'Exam',
#       'mark': 54}],
#     '5': [{'id': '40bcc06a01356d9dde8e93e7fe67512776728d99b6693bdc6782aea89b71002e',
#       'type': 'Test',
#       'mark': 79},
#      {'id': '9e04ca2a635f38b50db8439942f24ada46086fb4c2e00ee70f0b12b083576a6d',
#       'type': 'Project',
#       'mark': 72},
#      {'id': '2c405333f580c7e7b3d3874ede3bca6b748361ddd91d40eaad391c309d1eb0a9',
#       'type': 'Tutorials',
#       'mark': 85},
#      {'id': '02632a65cece30a2c73aecb16062f98902752ffee7b5b1dffc58e449cd39b6d8',
#       'type': 'Exam',
#       'mark': 61}],
#     '6': [{'id': '17a2c88643eb080bc8d271fa794ef78b5b65683cb45a3b30a107d44e4d793524',
#       'type': 'Test',
#       'mark': 71},
#      {'id': 'a06c34484d25c5a0b62c5d139ff2956a93d1775f46f2379193ee74e0d19bc0cc',
#       'type': 'Project',
#       'mark': 73},
#      {'id': '5cb7a0f6ad5c41314aee2a7324aa693a6e355a7c869efa9b496390da2922e041',
#       'type': 'Tutorials',
#       'mark': 52},
#      {'id': 'f7f5f2e6808d25b3085c10102f17f62c3a33f60757a2ff04e336238dc19131ba',
#       'type': 'Exam',
#       'mark': 52}],
#     '7': [{'id': '6cd8d88b1ac8fa06ebacecd7fa45995e3eeebc9371bf40ca84b506c3851e9546',
#       'type': 'Test',
#       'mark': 51},
#      {'id': '455f671b31b913d8a87ca03926559527e0a8398346e7b2fde2e4e4adda23fc85',
#       'type': 'Project',
#       'mark': 81},
#      {'id': 'b2aeba7f3236ad7599f1324f2151ad34ab2657987b5e5da39c34ee5080b52a20',
#       'type': 'Tutorials',
#       'mark': 59},
#      {'id': '59ce7a0ad791e6a682f164eb2478664e8ae373f590777b6e5819494450a08778',
#       'type': 'Exam',
#       'mark': 53}],
#     '8': [{'id': '0c3d57501260de64de2828914e46c0e8f6d536e8cd427b729bd67b912f5d5d00',
#       'type': 'Test',
#       'mark': 97},
#      {'id': '7f5158182e6e38ab9b0d72c692c046a69093c749162d491c72630f32c437a0b1',
#       'type': 'Project',
#       'mark': 67},
#      {'id': '2ac383b97ee555c9de46e958048db3a8570e290e9b690972b608fbf638338c34',
#       'type': 'Tutorials',
#       'mark': 79},
#      {'id': '4f85b90dec10c9786262442b0a9fe69fef7f81faece9da7b6526d72d68830775',
#       'type': 'Exam',
#       'mark': 52}],
#     '9': [{'id': '8acb2d4e9eb383ab051ffe258584795b5fa8169fe5e94de8b5e95346aa46cbd3',
#       'type': 'Test',
#       'mark': 88},
#      {'id': '3b7231616eb2340dd28f4475eb46283b6e0ce3740a41a9180f69bbab32c2f818',
#       'type': 'Project',
#       'mark': 68},
#      {'id': '96500773f3bdae8076639789263fe52dd43fb45026a649d6ebbfccfb3b0f30c1',
#       'type': 'Tutorials',
#       'mark': 86},
#      {'id': 'c90257b3463936b395932337282b5ec73d90247bd1c0f90de8becda9ea17c3e5',
#       'type': 'Exam',
#       'mark': 64}],
#     '10': [{'id': '711d20a1024b54f8155085244a210003d075a36d3b76bc507f2ed51e2dc10a48',
#       'type': 'Test',
#       'mark': 60},
#      {'id': '4dcaa39606a9a52fa6483a887d305dcbdae79819e5037ceb74f826abf7bcd3c8',
#       'type': 'Project',
#       'mark': 98},
#      {'id': '4df568d0cf0f75d60bae91d021db2af1740c9ee444ccd939a7c1a6e2fa5ffd6c',
#       'type': 'Tutorials',
#       'mark': 91},
#      {'id': '312f8d42f5795131e5f67db79b32918ba21477e3a13c27e8ae9920cdec765a9a',
#       'type': 'Exam',
#       'mark': 90}],
#     '11': [{'id': '3f4b4e69dec049ea8204de15b51e57a62ec85ee9f802fdb778c0ff03a0a69476',
#       'type': 'Test',
#       'mark': 79},
#      {'id': '09575774cfb3fdbeae7ba66963746fea30cc092b0952c16860e764f7babd9f3e',
#       'type': 'Project',
#       'mark': 50},
#      {'id': '28f4cae999b54e8927fd3e2c2c27bc659804dc0cf56491b352ced0b6b1e2b617',
#       'type': 'Tutorials',
#       'mark': 79},
#      {'id': 'e8939499efc8d6d8352f99724bac645c735723ba69bfea1b8cf12fe52616db87',
#       'type': 'Exam',
#       'mark': 74}],
#     '12': [{'id': '39630c84f53ae9fadef011fe47906029caf14cf995f4b70eefab51d3233383f9',
#       'type': 'Test',
#       'mark': 60},
#      {'id': 'c8db1e99be99aaa4f7ef3eeac4eee346a70fafaf86733ee3dc12ea5e60efc983',
#       'type': 'Project',
#       'mark': 73},
#      {'id': '8a7a1f859511e9ae163b2e9b52aca4c37b5f1e042658b62bd6e9c200bd91519a',
#       'type': 'Tutorials',
#       'mark': 45},
#      {'id': '9a58c08c922f46862b6deada1d4f9e0fb8b11e34aa75dfbaf03a24a33b3c36a6',
#       'type': 'Exam',
#       'mark': 55}],
#     '13': [{'id': 'fa8cf34ccc816d87b7f500043eeb18b39db441e34794b5a894f8c34022fc86e6',
#       'type': 'Test',
#       'mark': 46},
#      {'id': '34ed8ce4066bb317551f8f40ee7111a8824875bf4085c48ede3affa027ac9afe',
#       'type': 'Project',
#       'mark': 93},
#      {'id': 'c23afc8ed9ea3a70ea51554e0dd20a9b5498663ded9be60a913e32d1980eb26d',
#       'type': 'Tutorials',
#       'mark': 94},
#      {'id': 'e4c01669235b64be61836d46e8ed7f7344d5094c9d3a05b221fa954bc662377b',
#       'type': 'Exam',
#       'mark': 68}]}}}}

# %%
t0 = time.time()
_get_marks_by_student('4')
print(time.time() - t0)

# %%
def get_asset_data(_id):
    asset = mbc.assets.find_one({'id': _id})
    return asset['data']

def get_asset_metadata(asset_id):
    transactions = list(mbc.transactions.find({'asset.id': asset_id}))
    if transactions:
        return mbc.metadata.find_one({'id': transactions[-1]['id']})['metadata']
    else:
        return mbc.metadata.find_one({'id': asset_id})['metadata']

# %%
def get_student_mark_assets(student_address):
    return list(mbc.assets.find({'data.asset_type':'mark', 'data.student_address': student_address}))

def process(mark_assets):
    course_ids = list()
    degree_ids = list()
    marks = dict()

    for m in mark_assets:
        course_id = m['data']['course_id']
        degree_id = m['data']['degree_id']
        mark_metadata = get_asset_metadata(m['id'])
        
        if not marks.get(course_id):
            marks[course_id] = dict()
            marks[course_id]['components'] = {m['data']['type']: {'mark': mark_metadata['mark'], 'timestamp': mark_metadata['timestamp']}, 'degree_id': m['data']['degree_id']}
        else:
            marks[course_id]['components'][m['data']['type']] = {'mark': mark_metadata['mark'], 'timestamp': mark_metadata['timestamp'], 'degree_id': m['data']['degree_id']}
            
        course_ids.append(course_id)
        degree_ids.append(degree_id)
        
    course_ids = list(set(course_ids))
    degree_ids = list(set(degree_ids))
    
    return (degree_ids, course_ids, marks)

def add_course_info(marks, course_ids):
    for course_id in course_ids:
        course_asset = get_asset_data(course_id)
        course_metadata = get_asset_metadata(course_id)
        
        if marks.get(course_id).get('year', '1900') < course_metadata['timestamp'][:4]:
            marks.get(course_id)['year'] = course_metadata['timestamp'][:4]
        
        marks[course_id] = {**marks[course_id], **course_asset}
        for c in course_metadata['components']:
            marks[course_id]['components'][c['type']]['weighting'] = c['weighting']
            
    return marks

def add_degree_info(marks, degree_ids):
    degree_data = dict()
    for degree_id in degree_ids:
        degree_data[degree_id] = {**get_asset_data(degree_id), **get_asset_metadata(degree_id)}
    return {'degree_data': degree_data, 'mark_data': marks}

def _get_marks_by_student2(student_address):
    mark_assets = get_student_mark_assets(student_address)
    degree_ids, course_ids, mark_data = process(mark_assets)
    mark_data = add_course_info(mark_data, course_ids)
    mark_data = add_degree_info(mark_data, degree_ids)
    return mark_data

# %%
t0 = time.time()
_get_marks_by_student2('4')
print(time.time() - t0)
